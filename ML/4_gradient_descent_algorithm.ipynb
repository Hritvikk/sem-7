# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.arange(-5,5)
Y = (X+3)**2
plt.style.use("seaborn")
plt.plot(X,Y)
plt.xlabel("X")
plt.ylabel("F(X)")
plt.show()

# %%
x = 0
lr = 0.1
error = []
steps=50
plt.plot(X,Y)
for i in range(steps):
    grad = 2*(x+3)
    x = x - lr*grad
    e = (x+3)**2
    error.append(e)
    plt.scatter(x,e)
    plt.xlabel("X")
    plt.ylabel("F(X)")
    print(x)
# Out:
# -0.6000000000000001
# -1.08
# -1.464
# -1.7711999999999999
# -2.01696
# -2.213568
# -2.3708544
# -2.49668352
# -2.597346816
# -2.6778774528
# -2.74230196224
# -2.793841569792
# -2.8350732558336
# -2.86805860466688
# -2.894446883733504
# -2.9155575069868034
# -2.932446005589443
# -2.945956804471554
# -2.9567654435772432
# -2.9654123548617948
# -2.9723298838894356
# -2.9778639071115487
# -2.982291125689239
# -2.985832900551391
# -2.988666320441113
# -2.9909330563528904
# -2.9927464450823122
# -2.99419715606585
# -2.99535772485268
# -2.996286179882144
# -2.997028943905715
# -2.9976231551245722
# -2.9980985240996576
# -2.9984788192797263
# -2.998783055423781
# -2.999026444339025
# -2.99922115547122
# -2.9993769243769757
# -2.9995015395015807
# -2.9996012316012646
# -2.9996809852810116
# -2.999744788224809
# -2.9997958305798473
# -2.999836664463878
# -2.9998693315711025
# -2.999895465256882
# -2.9999163722055053
# -2.999933097764404
# -2.9999464782115233
# -2.9999571825692186
